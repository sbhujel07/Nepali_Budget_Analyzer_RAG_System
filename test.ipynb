# %%
# !pip install pymupdf
# Out:
# Requirement already satisfied: pymupdf in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (1.27.2.2)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pytesseract) (26.0)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from pytesseract) (12.2.0)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import re

def clean_text(text):
    # remove page markers like --- Page 1 ---
    text = re.sub(r"--- Page \d+ ---", "", text)
    
    # remove standalone page numbers (lines with only numbers)
    text = re.sub(r"^\s*\d+\s*$", "", text, flags=re.MULTILINE)
    
    # remove OCR garbage like .१10.80४.110
    text = re.sub(r"\.\d*[०-९\d./]+", "", text)
    
    # remove multiple newlines
    text = re.sub(r"\n{2,}", "\n", text)
    
    # remove extra spaces
    text = re.sub(r"\s{2,}", " ", text)
    
    return text.strip()

# %%
from pdf2image import convert_from_path
import pytesseract
import os

# -----------------------------
# 1. Setup paths
# -----------------------------

# Path to Tesseract OCR executable
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# Path to Poppler bin folder
poppler_path = r"C:\Program Files\poppler-25.12.0\Library\bin"

# PDF file path
pdf_path = r"budget_speech_2081.pdf"

# Output text file
output_text_file = r"budget_speech_text.txt"

# -----------------------------
# 2. Convert PDF to images
# -----------------------------
try:
    images = convert_from_path(pdf_path, dpi=300, poppler_path=poppler_path)
    print(f"Number of pages found: {len(images)}")
except Exception as e:
    print("Error converting PDF to images:", e)
    exit()

# -----------------------------
# 3. Extract text from images
# -----------------------------
def extract_text_from_images(images):
    extracted_text = []
    for i, page in enumerate(images):
        text = pytesseract.image_to_string(page, lang="nep")
        text = clean_text(text)
        extracted_text.append({
            "page_number": i,
            "text": text
        })
    return extracted_text

text_data = extract_text_from_images(images)

# -----------------------------
# 4. Save text to file
# -----------------------------
with open(output_text_file, "w", encoding="utf-8") as f:
    for page in text_data:
        f.write(f"--- Page {page['page_number']} ---\n")
        f.write(page['text'])
        f.write("\n\n")

print(f"Extraction completed! Text saved to {output_text_file}")

# -----------------------------
# 5. Optional: print first page text
# -----------------------------
if text_data:
    print("\nFirst page preview:\n")
    print(text_data[0]["text"])
# Out:
# Number of pages found: 111
# Extraction completed! Text saved to budget_speech_text.txt
#
# First page preview:
#
# संघीय संसदको संयुक्त बेठकमा २०८१ साल जेठ १५ गते
# संगलबार
# अर्थमन्त्री वर्षमान पुन 'अनन्त' ले
# प्रस्तुत गर्नु भएको
# आर्थिक वर्ष २०८१/८२ को
# बजेट वक्तव्य
# नेपाल सरकार
# अर्थ मन्त्रालय
# ५४/५/४५४४

# %%
text_data[10]
# Out:
# {'page_number': 10,
्छु।\nकृषि क्षेत्रको रूपान्तरण\n३१.\nकृषिको व्यावसायीकरण र आधुनिकीकरण गरी उत्पादन र उत्पादकत्व\nअभिवृद्धि गरिनेछ। सरकारी, निजी, सहकारी तथा विकास साझेदारबाट\nकृषि क्षेत्रमा लगानी अभिवृद्धि गर्न विक्रम सम्वत्\u200c २०८१ देखि२०९१\nसम्मको अवधिलाई कृषिमा लगानी दशक घोषणा गरिएको छ। भूगोल,\nबजार सम्भाव्यता एवं पारिस्थितिकीय विशिष्टता अनुकूल संघ, प्रदेश र\nस्थानीय तहबाट कृषि उपजको विशेष क्षेत्र पहिचान गरी उत्पादन प्रवर्द्धन\nगरिनेछ।'}

# %% [markdown]
# Now lets make the text more cleaner

# %%
import pandas as pd
pd = pd.DataFrame(text_data)

# %%
pd.head()
# Out:
#    page_number                                               text
# 0            0  संघीय संसदको संयुक्त बेठकमा २०८१ साल जेठ १५ गत...
# 1            1  प्रतिनिधि सभाका सम्माननीय सभामुख महोदय,\nराष्ट...
# 2            2  ५. तेस्रो लगानी सम्मेलन उत्साहपूर्ण रूपमा सम्प...
# 3            3  १०.\n११.\nआर्थिक वर्ष २०६४/६५ मा रु खर्ब १५ अर...
# 4            4  १३.\n१४.\nप्रतिहजार ६१ बाट ३३ मा र मातृ मृत्यु...

# %%
import random
random.sample(text_data,k=1)
# Out:
# [{'page_number': 31,
#   'text': '१३३.\n१३४.\n१३५.\n१३६.\n१२३७.\n१३८.\nरोजगार बैंकको स्थापना गरी रोजगारीसम्बन्धी सूचनाको एकीकृत\nअभिलेख तयार गरिनेछ। श्रम बजारमा उपलव्ध रोजगारीको अवसर\nतथा जनशक्तिको माग र आपूर्तिलाई स्वचालित प्रणालीमा आवद्ध\nगरिनेछ। श्रम र रोजगारीसम्बन्धी सेवा प्रवाह र गुनासो सम्बोधनका\nलागि श्रमाधान कार्यक्रम सञ्चालन गरिनेछ ।\nप्रधानमन्त्री रोजगार कार्यक्रम अन्तर्गत स्थानीय तहमा सूचीकृत\nबेरोजगारलाई सार्वजनिक निर्माण तथा मर्मत सम्भार आयोजनाका काममा\nसहभागी गराई करिब दुई लाख व्यक्तिलाई न्यूनतम सय दिनको रोजगारी\nप्रदान गरिनेछ। यस कार्यक्रमका लागि रु. ६ अर्ब विनियोजन गरेको\nछु।\nवैदेशिक रोजगारीलाई सुरक्षित र व्यवस्थित गरिनेछ। वैदेशिक\nरोजगारीलाई थप व्यवस्थित गर्न कूटनीतिक नियोगलाई प्रभावकारी\nरूपमा परिचालन गरिनेछ। गन्तव्य मुलुकमा अलेखबद्ध श्रमिकको दर्ता\nगर्ने कार्यलाई अभियानको रूपमा सञ्चालन गरिनेछ।\nआगामी आर्थिक वर्ष थप तीन प्रमुख गन्तव्य मुलुकसँग द्विपक्षीय श्रम\nसम्झौता गरिनेछ। वैदेशिक रोजगारीमा जाने श्रमिकलाई सीपयुक्त\nबनाइनेछ। वैदेशिक रोजगारीमा जानुपूर्व गरिने अभिमुखीकरण\nतालीमलाई क्रमशः निःशुल्क गर्ने व्यवस्था गरिनेछ ।\nवैदेशिक रोजगारीमा गएका श्रमिकका आश्रित परिवारलाई कल्याणकारी\nकोषबाट प्रदान हुने लाभको दायरा विस्तार गरिनेछ। यससम्बन्धी सेवा\nस्थानीय तहबाट प्रवाह हुने व्यवस्था मिलाइनेछ।\nवैदेशिक रोजगारीबाट फर्किएका नागरिकको ज्ञान, सीप र पुँजी मार्फत\nउद्यमशीलता प्रवर्द्धन गर्न रिटर्नी उचमशीलता कार्यक्रम सञ्चालन गरी\nकम्तीमा एक लाख रिटर्नीलाई स्वरोजगार बनाइनेछ। वैदेशिक'}]

# %% [markdown]
# Lets preprocess further.So split the sentences using Spacy,like split the each sentences in pages.

# %%
# import spacy

# nlp = spacy.blank("ne")
# nlp.add_pipe("sentencizer")

# #for demo
# text = "मलाई नेपाली भाषा मन पर्छ। यो धेरै सुन्दर भाषा हो। म काठमाडौंमा बस्छु।"

# doc = nlp(text)

# for sent in doc.sents:
#     print(sent.text)
# Out:
# मलाई नेपाली भाषा मन पर्छ।
# यो धेरै सुन्दर भाषा हो।
# म काठमाडौंमा बस्छु।

# %% [markdown]
# Lets use the spacy for our text dataset

# %%
# for items in text_data:
#     doc = nlp(items["text"])
#     items["Sentence"] = [str(sentence).strip() for sentence in doc.sents]
#     items["Sentence_count"] = len(items["Sentence"])

# text_data[3]
# Out:
# {'page_number': 3,
#  'text': '१०.\n११.\nआर्थिक वर्ष २०६४/६५ मा रु खर्ब १५ अर्ब रहेको कुल गार्हस्थ्य\nउत्पादन चालु आर्थिक वर्ष रु. ५७ खर्ब ५ अर्ब हुने अनुमान छ। प्रति\nव्यक्ति राष्ट्रिय आय अमेरिकी डलर ४ सय ९१ बाट बढेर १ हजार ४\nसय ५६ पुगेको छ। विद्युत उत्पादन ७ सय मेगावाटबाट ३ हजार\n६० मेगावाट पुगेको छ । यसबीच ५६ प्रतिशतबाट बढेर ९८ प्रतिशत\nजनसंख्यामा विद्युत सेवाको पहुँच पुगेको छ।\n२०६५ सालमा कालोपत्रे सडक ५ हजार ४ सय किलोमिटर रहेकोमा\nहाल १८ हजार २ सय ४१ किलोमिटर पुगेको छ। ६१ जिल्ला सडक\nसञ्जालमा जोडिएकोमा हाल मुलुकका सबै जिल्ला राष्ट्रिय सडक\nसञ्जालमा जोडिएका छन्\u200c। मुलुकमा सबै स्तरका गरी १ लाख ५ हजार\nकिलोमिटर सडक रहेको छ। २०६५ सालमा वाणिज्य बैंकका ५ सय\n९१ शाखा रहेकोमा हाल ५ हजार ४२ शाखा सञ्चालनमा रहेका छन्\u200c।\nगणतन्त्र स्थापना पश्चात मुलुकमा स्रोत र साधनको वितरण समानतातर्फ\nउन्मुख हुँदै गएको छ। नेपाल जीवनस्तर सर्वेक्षण २०६०/६१ मा\nअसमानता गणना गर्ने जिनी सूचकाङ्क ० रहेकोमा पछिल्लो सर्वेक्षणमा\nसुधार भई ० कायम भएको छ। २०६५ सालमा निरपेक्ष गरिबी\n३० प्रतिशत रहेकोमा हाल घटेर २० प्रतिशत पुगेको छ। त्यसैगरी\nमानव विकास सूचकाङ्क ० बाट बढेर ० कायम भएको\nछ। नेपालीको औसत आयु ६० वर्षबाट बढेर ७१ वर्ष पुगेको\nछ। साक्षरता दर ५८ प्रतिशत बाट बढेर ७६ प्रतिशत पुगेको छ।\nआधारभूत खानेपानीको पहुँच ४५ बाट बढेर ९७ प्रतिशत जनसंख्यामा\nपुगेको छ।\nसम्वत्\u200c २०६४ मा शिशु मृत्युदर प्रतिहजार जीवित जन्ममा ४८ रहेकोमा\nहाल २१ मा झरेको छ। त्यसैगरी पाँच वर्ष मुनिको बाल मृत्युदर',
#  'Sentence': ['१०.',
#   '११.',
#   'आर्थिक वर्ष २०६४/६५ मा रु खर्ब १५ अर्ब रहेको कुल गार्हस्थ्य\nउत्पादन चालु आर्थिक वर्ष रु.',
#   '५७ खर्ब ५ अर्ब हुने अनुमान छ।',
#   'प्रति\nव्यक्ति राष्ट्रिय आय अमेरिकी डलर ४ सय ९१ बाट बढेर १ हजार ४\nसय ५६ पुगेको छ।',
#   'विद्युत उत्पादन ७ सय मेगावाटबाट ३ हजार\n६० मेगावाट पुगेको छ ।',
#   'यसबीच ५६ प्रतिशतबाट बढेर ९८ प्रतिशत\nजनसंख्यामा विद्युत सेवाको पहुँच पुगेको छ।',
#   '२०६५ सालमा कालोपत्रे सडक ५ हजार ४ सय किलोमिटर रहेकोमा\nहाल १८ हजार २ सय ४१ किलोमिटर पुगेको छ।',
#   '६१ जिल्ला सडक\nसञ्जालमा जोडिएकोमा हाल मुलुकका सबै जिल्ला राष्ट्रिय सडक\nसञ्जालमा जोडिएका छन्\u200c।',
#   'मुलुकमा सबै स्तरका गरी १ लाख ५ हजार\nकिलोमिटर सडक रहेको छ।',
#   '२०६५ सालमा वाणिज्य बैंकका ५ सय\n९१ शाखा रहेकोमा हाल ५ हजार ४२ शाखा सञ्चालनमा रहेका छन्\u200c।',
#   'गणतन्त्र स्थापना पश्चात मुलुकमा स्रोत र साधनको वितरण समानतातर्फ\nउन्मुख हुँदै गएको छ।',
#   'नेपाल जीवनस्तर सर्वेक्षण २०६०/६१ मा\nअसमानता गणना गर्ने जिनी सूचकाङ्क ० रहेकोमा पछिल्लो सर्वेक्षणमा\nसुधार भई ० कायम भएको छ।',
#   '२०६५ सालमा निरपेक्ष गरिबी\n३० प्रतिशत रहेकोमा हाल घटेर २० प्रतिशत पुगेको छ।',
#   'त्यसैगरी\nमानव विकास सूचकाङ्क ० बाट बढेर ० कायम भएको\nछ।',
#   'नेपालीको औसत आयु ६० वर्षबाट बढेर ७१ वर्ष पुगेको\nछ।',
#   'साक्षरता दर ५८ प्रतिशत बाट बढेर ७६ प्रतिशत पुगेको छ।',
#   'आधारभूत खानेपानीको पहुँच ४५ बाट बढेर ९७ प्रतिशत जनसंख्यामा\nपुगेको छ।',
#   'सम्वत्\u200c २०६४ मा शिशु मृत्युदर प्रतिहजार जीवित जन्ममा ४८ रहेकोमा\nहाल २१ मा झरेको छ।',
#   'त्यसैगरी पाँच वर्ष मुनिको बाल मृत्युदर'],
#  'Sentence_count': 20}

# %% [markdown]
# Spacy ley hamro data ma jaha jaha ru xa tya ni split garyo so yesley context bigaryo then lets split manually

# %%
import re

#define splitter  func
def split_nepali_sentences(text):
    abbreviations = ['रु', 'डा', 'श्री', 'नं', 'क्र', 'पृ']
    text = text.replace('\n', ' ')
    for abbr in abbreviations:
        text = text.replace(abbr + '.', abbr + '###')
    
    sentences = re.split(r'(?<=[।॥!?])\s+', text)
    sentences = [s.replace('###', '.') for s in sentences]
    sentences = [s.strip() for s in sentences 
                 if s.strip() and not re.fullmatch(r'[०-९]+\.', s.strip())]
    return sentences

# %%
# #delete the spacy splitter
# for items in text_data:
#     del items["Sentence"]
#     del items["Sentence_count"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 4
#       1 #delete the spacy splitter
#       2 for items in text_data:
#       3     del items["Sentence"]
# ----> 4     del items["Sentence_count"]
#
# KeyError: 'Sentence_count'

# %%
text_data[0]
# Out:
# {'page_number': 0,
#  'text': "संघीय संसदको संयुक्त बेठकमा २०८१ साल जेठ १५ गते\nसंगलबार\nअर्थमन्त्री वर्षमान पुन 'अनन्त' ले\nप्रस्तुत गर्नु भएको\nआर्थिक वर्ष २०८१/८२ को\nबजेट वक्तव्य\nनेपाल सरकार\nअर्थ मन्त्रालय\n५४/५/४५४४"}

# %%
for items in text_data:
    items["Sentence"] = split_nepali_sentences(items["text"])
    items["Sentence_Count"] = len(items["Sentence"])

# %%
text_data[0]
# Out:
# {'page_number': 0,
#  'text': "संघीय संसदको संयुक्त बेठकमा २०८१ साल जेठ १५ गते\nसंगलबार\nअर्थमन्त्री वर्षमान पुन 'अनन्त' ले\nप्रस्तुत गर्नु भएको\nआर्थिक वर्ष २०८१/८२ को\nबजेट वक्तव्य\nनेपाल सरकार\nअर्थ मन्त्रालय\n५४/५/४५४४",
#  'Sentence': ["संघीय संसदको संयुक्त बेठकमा २०८१ साल जेठ १५ गते संगलबार अर्थमन्त्री वर्षमान पुन 'अनन्त' ले प्रस्तुत गर्नु भएको आर्थिक वर्ष २०८१/८२ को बजेट वक्तव्य नेपाल सरकार अर्थ मन्त्रालय ५४/५/४५४४"],
#  'Sentence_Count': 1}

# %%
text_data[10]
# Out:
# {'page_number': 10,
#  'text': '२७. सशर्त अनुदान प्रदेशको लागि रु. २५ अर्ब ८४ करोड र स्थानीय तहको\nलागि रु. २ खर्ब ८ अर्ब ८८ करोड गरी जम्मा रु. २ खर्ब ३४ अर्ब\n७३ करोड हस्तान्तरणको लागि विनियोजन गरेको छु।\n२८. प्रदेश र स्थानीय तहलाई पूर्वाधारका आयोजना कार्यान्वयन गर्न समपूरक\nअनुदान क्रमशः रु. ६ अर्ब २० करोड र रु. ७ अर्ब विनियोजन गरेको\nछु। विशेष अनुदान प्रदेशको लागि रु. ४ अर्ब ४० करोड र स्थानीय\nतहको लागि रु. ८ अर्ब ५० करोड विनियोजन गरेको छु। सशर्त,\nसमपूरक र विशेष अनुदान कार्यसम्पादनका आधारमा हस्तान्तरण गर्ने\nव्यवस्था मिलाएको छु।\n२९, प्रदेश र स्थानीय तहमा राजस्व बाँडफाँटबाट रु. १ खर्ब १९ अर्ब\nहस्तान्तरण हुने अनुमान छ।\n३०. राजस्व बाँड
# %% [markdown]
# For Chunking Strategy lets use the sliding Window.Yesma k hunxa vanda kati number of sentence ligdai janey and we also define a overlap jasma 1st chunking ko last sentence 2nd chunking ko first sentence hunxa yesley context ko semantic preserve garxa.

# %%
def create_chunks(data,chunk_size=3,overlap=1):
    all_chunks = []

    steps = chunk_size-overlap
    for items in data:
        page_number = items["page_number"]
        sentence = items["Sentence"]


        #for each page and sentence
        for i in range(0,len(sentence),steps):
            chunks_sentence = sentence[i:i+chunk_size]
            chunks_sentence = "".join(chunks_sentence)
            all_chunks.append({"Page_number":page_number,
                               "Chunk_Text":chunks_sentence,
                               "Chunk_Count":len(chunks_sentence)})

    return all_chunks

# %%
Chunks = create_chunks(text_data)

# %%
Chunks[10]
# Out:
# {'Page_number': 2,
#  'Chunk_Text': 'यस अवधिमा आर्थिक तथा सामाजिक क्षेत्रमा हासिल भएका मुख्य उपलब्धि प्रस्तुत गर्ने अनुमति चाहन्छु।',
#  'Chunk_Count': 94}

# %%
print(len(Chunks))
# Out:
# 498

# %%
print(len(text_data))
# Out:
# 111

# %%
import pandas as pd
df = pd.DataFrame(Chunks)

# %%
df.head(5)
# Out:
#    Page_number                                         Chunk_Text  Chunk_Count
# 0            0  संघीय संसदको संयुक्त बेठकमा २०८१ साल जेठ १५ गत...          183
# 1            1  प्रतिनिधि सभाका सम्माननीय सभामुख महोदय, राष्ट्...          550
# 2            1  नेपालका प्रथम शहीद लखन थापा, २००७ सालको परिवर्...          427
# 3            1  केही समयदेखि शिथिल रहेको मुलुकको अर्थतन्त्र सर...          456
# 4            1  संविधानको परिकल्पना अनुसार राष्ट्रिय अर्थतन्त्...          472

# %%
df.head(10)
# Out:
#    Page_number                                         Chunk_Text  Chunk_Count
# 0            0  संघीय संसदको संयुक्त बेठकमा २०८१ साल जेठ १५ गत...          183
# 1            1  प्रतिनिधि सभाका सम्माननीय सभामुख महोदय, राष्ट्...          550
# 2            1  नेपालका प्रथम शहीद लखन थापा, २००७ सालको परिवर्...          427
# 3            1  केही समयदेखि शिथिल रहेको मुलुकको अर्थतन्त्र सर...          456
# 4            1  संविधानको परिकल्पना अनुसार राष्ट्रिय अर्थतन्त्...          472
# 5            1  समृद्ध नेपाल, सुखी नेपालीको राष्ट्रिय आकांक्षा...          152
# 6            2  ५. तेस्रो लगानी सम्मेलन उत्साहपूर्ण रूपमा सम्प...          308
# 7            2  लगानीसम्बन्धी आठ कानूनमा एकैपटक गरिएको सुधारले...          328
# 8            2  नागरिकको जीवनमा अनुभूतयोग्य परिवर्तन हासिल गर्...          619
# 9            2  संसदका विषयगत समिति, प्रदेश तथा स्थानीय तह, रा...          388

# %% [markdown]
# Now lets filter the chunks like if chunks has no words and chunk length less than 30.

# %%
filtered_chunks = [chunk for chunk in Chunks 
                    if chunk["Chunk_Text"] #if chunks has text
                  and  chunk["Chunk_Text"].strip() != ""  #if chunks is not empty
                  and len(chunk["Chunk_Text"]) > 30
                    ]

# %%
filtered_chunks[1]
# Out:
# {'Page_number': 1,
#  'Chunk_Text': 'प्रतिनिधि सभाका सम्माननीय सभामुख महोदय, राष्ट्रिय सभाका सम्माननीय अध्यक्ष महोदय, १. नेपाल सरकारको अर्थमन्त्रीको हैसियतले आर्थिक वर्ष २०८१/८२ को बजेट प्रस्तुत गर्न यस सम्मानित सदनमा उपस्थित भएको छु।सर्वप्रथम सत्रौं गणतन्त्र दिवसको अवसरमा सम्पूर्ण नेपाली दिदीबहिनी तथा दाजुभाइमा हार्दिक शुभकामना व्यक्त गर्दछु।नेपालका प्रथम शहीद लखन थापा, २००७ सालको परिवर्तन, २०४६ सालको आन्दोलन, २०५२ सालको जनयुद्ध, २०६२/६३ को जनआन्दोलन, मधेश आन्दोलन, आदिबासी जनजाति आन्दोलन लगायतका सम्पूर्ण लोकतान्त्रिक आन्दोलनका महान शहीदहरूप्रति हार्दिक श्रद्धाञ्जली अर्पण गर्दछु ।',
#  'Chunk_Count': 550}

# %%
print(len(Chunks))
print(len(filtered_chunks))
# Out:
# 498
# 492

# %% [markdown]
# now we gonna use the Sentence Transformer from Hugging face 'paraphrase-multilingual-MiniLM-L12-v2'  for Embeddings

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\DELL\.cache\huggingface\hub\models--sentence-transformers--paraphrase-multilingual-MiniLM-L12-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 1499.87it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
#Now Embeddings

for chunk in filtered_chunks:
    chunk["Chunk_Embedding"] = model.encode(chunk["Chunk_Text"]).tolist()

# %%
filtered_chunks[1]
# Out:
# {'Page_number': 1,
#  'Chunk_Text': 'प्रतिनिधि सभाका सम्माननीय सभामुख महोदय, राष्ट्रिय सभाका सम्माननीय अध्यक्ष महोदय, १. नेपाल सरकारको अर्थमन्त्रीको हैसियतले आर्थिक वर्ष २०८१/८२ को बजेट प्रस्तुत गर्न यस सम्मानित सदनमा उपस्थित भएको छु।सर्वप्रथम सत्रौं गणतन्त्र दिवसको अवसरमा सम्पूर्ण नेपाली दिदीबहिनी तथा दाजुभाइमा हार्दिक शुभकामना व्यक्त गर्दछु।नेपालका प्रथम शहीद लखन थापा, २००७ सालको परिवर्तन, २०४६ सालको आन्दोलन, २०५२ सालको जनयुद्ध, २०६२/६३ को जनआन्दोलन, मधेश आन्दोलन, आदिबासी जनजाति आन्दोलन लगायतका सम्पूर्ण लोकतान्त्रिक आन्दोलनका महान शहीदहरूप्रति हार्दिक श्रद्धाञ्जली अर्पण गर्दछु ।',
#  'Chunk_Count': 550,
#  'Chunk_Embedding': [-0.18937717378139496,
#   0.22754260897636414,
#   0.19015610218048096,
#   -0.051531095057725906,
#   0.035798173397779465,
#   0.1601756513118744,
#   0.003642766736447811,
#   0.03503340482711792,
#   0.004940975457429886,
#   0.19260723888874054,
#   -0.03422952815890312,
#   -0.11836128681898117,
#   0.14527559280395508,
#   0.029131941497325897,
#   0.14834704995155334,
#   0.03794708102941513,
#   -0.1269800066947937,
#   -0.06829263269901276,
#   -0.14242441952228546,
#   -0.03582633286714554,
#   -0.03501779958605766,
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384
# 384

# %% [markdown]
# Now take the text chunks only and store then do embeddings

# %%
text_chunks = [chunk["Chunk_Text"] for chunk in filtered_chunks]

# %%
text_chunks[1]
# Out:
# 'प्रतिनिधि सभाका सम्माननीय सभामुख महोदय, राष्ट्रिय सभाका सम्माननीय अध्यक्ष महोदय, १. नेपाल सरकारको अर्थमन्त्रीको हैसियतले आर्थिक वर्ष २०८१/८२ को बजेट प्रस्तुत गर्न यस सम्मानित सदनमा उपस्थित भएको छु।सर्वप्रथम सत्रौं गणतन्त्र दिवसको अवसरमा सम्पूर्ण नेपाली दिदीबहिनी तथा दाजुभाइमा हार्दिक शुभकामना व्यक्त गर्दछु।नेपालका प्रथम शहीद लखन थापा, २००७ सालको परिवर्तन, २०४६ सालको आन्दोलन, २०५२ सालको जनयुद्ध, २०६२/६३ को जनआन्दोलन, मधेश आन्दोलन, आदिबासी जनजाति आन्दोलन लगायतका सम्पूर्ण लोकतान्त्रिक आन्दोलनका महान शहीदहरूप्रति हार्दिक श्रद्धाञ्जली अर्पण गर्दछु ।'

# %%
#Do embeddings to text chunk only
text_chunks_embeddings = model.encode(text_chunks,
                                       batch_size = 16,
                                       convert_to_tensor = False ) #Convert to tensor false because paxi vector database ma pathauda numpy chainxa not tensor so

# %%
text_chunks_embeddings[1]
# Out:
# array([-1.89377174e-01,  2.27542609e-01,  1.90156102e-01, -5.15310951e-02,
#         3.57981734e-02,  1.60175651e-01,  3.64276674e-03,  3.50334048e-02,
#         4.94097546e-03,  1.92607239e-01, -3.42295282e-02, -1.18361287e-01,
#         1.45275593e-01,  2.91319415e-02,  1.48347050e-01,  3.79470810e-02,
#        -1.26980007e-01, -6.82926327e-02, -1.42424420e-01, -3.58263329e-02,
#        -3.50177996e-02,  6.96112663e-02, -9.59864818e-03, -9.57301185e-02,
#         2.90983677e-01, -1.78734764e-01,  1.42835766e-01, -4.18034978e-02,
#         2.56769154e-02,  3.20971943e-03, -3.83310206e-02, -7.27589875e-02,
#         2.24789545e-01,  8.16226304e-02,  3.47466441e-03,  2.07328409e-01,
#         2.09680423e-01,  1.05819747e-01,  8.38068277e-02,  1.05811782e-01,
#        -1.22067943e-01, -1.08447619e-01,  1.47002742e-01,  1.53525556e-02,
#         1.07549019e-01, -4.93621603e-02, -2.41544750e-02, -5.15993536e-02,
#        -2.37045199e-01,  1.13490827e-01,  1.24577582e-01, -1.28844695e-03,
#        -2.14250147e-01, -1.98667999e-02,  1.10691808e-01, -1.23339584e-02,
#         4.75443620e-03, -1.33892940e-02,  3.01841162e-02, -1.29338428e-01,
#        -5.99057749e-02,  1.36085957e-01, -2.95904651e-03,  1.70158207e-01,
#        -1.77159607e-01, -1.15695156e-01,  1.52549475e-01, -1.06047451e-01,
#        -1.43974483e-01,  1.12703770e-01, -1.04458734e-01,  8.64235610e-02,
#         1.69547349e-01, -2.53499925e-01, -1.60411373e-01, -3.03497791e-01,
#         4.50333534e-03,  2.10014194e-01, -1.27098724e-01, -7.41372183e-02,
#         1.18072093e-01,  2.48889714e-01,  6.13535680e-02,  7.04064220e-03,
#        -4.53106537e-02,  7.85858463e-03,  4.35091890e-02, -6.40649796e-02,
#         6.98036402e-02, -2.10423291e-01, -1.09986626e-01,  1.67236969e-01,
